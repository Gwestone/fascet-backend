# %%
import numpy as np
from scipy.spatial import Voronoi, voronoi_plot_2d
import matplotlib.pyplot as plt

# %% [markdown]
# # Generate initial points

# %%
points = np.random.rand(50, 2)

# %% [markdown]
# # Create Subdiv2D object and insert initial points

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import Voronoi, voronoi_plot_2d

# Generate some random points
num_points = 500
points = np.random.rand(num_points, 2)

# Create initial Voronoi diagram
vor = Voronoi(points)

# Iteratively improve Voronoi diagram using Lloyd's Algorithm
num_iterations = 0
for i in range(num_iterations):
    centroids = []
    for region in vor.regions:
        if not region: continue
        polygon = [vor.vertices[i] for i in region]
        centroid = np.sum(polygon, axis=0) / len(polygon)
        centroids.append(centroid)
    points = np.array(centroids)
    vor = Voronoi(points)

# Plot final Voronoi diagram
fig = voronoi_plot_2d(vor, show_vertices=False)
plt.scatter(points[:,0], points[:,1], c='r')
plt.show()
